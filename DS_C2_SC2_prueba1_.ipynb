# %%
#Recuperar la información del archivo
#Obtener la estructura y tipos de dato de cada columna
#Cantidad de vacunas aplicadas de cada compañía
#Cantidad de vacunas aplicadas en todo el mundo
#Promedio de vacunas aplicadas por país
#Cantidad de vacunas aplicadas el día 29/01/21
#Dataframe nuevo llamado conDiferencias
#Obtener la diferencia de tiempo
#Dataframe nuevo llamado conCantidad
#Dataframe llamado antes20
#Dataframe llamado pfizer
#Almacenar los dataframes

# %% [markdown]
# # Nueva sección

# %%
#Librerias
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-89a9f6da-45df-4f09-8da7-cfd8c3157d5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89a9f6da-45df-4f09-8da7-cfd8c3157d5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Recuperar la información del archivo
# Carga el archivo CSV
file_path = "/country_vaccinations.csv"
df = pd.read_csv(file_path)

# %%
# Muestra las primeras filas del dataframe
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
# Muestra la información del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  object
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
# ...

# %%
# Muestra estadísticas descriptivas de las columnas numéricas
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        4.360700e+04       4.129400e+04             3.880200e+04
# mean         4.592964e+07       1.770508e+07             1.413830e+07
# std          2.246004e+08       7.078731e+07             5.713920e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          5.264100e+05       3.494642e+05             2.439622e+05
# 50%          3.590096e+06       2.187310e+06             1.722140e+06
# 75%          1.701230e+07       9.152520e+06             7.559870e+06
# max          3.263129e+09       1.275541e+09             1.240777e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            3.536200e+04        8.621300e+04
# mean             2.705996e+05        1.313055e+05
# std              1.212427e+06        7.682388e+05
# min              0.000000e+00        0.000000e+00
# 25%              4.668000e+03        9.000000e+02
# ...

# %%
# Muestra estadísticas descriptivas de las columnas categóricas
df.describe(include="object")
# Out:
#        country iso_code        date  \
# count    86512    86512       86512
# unique     223      223         483
# top     Norway      NOR  2021-08-26
# freq       482      482         220
#
#                                                  vaccines  \
# count                                               86512
# unique                                                 84
# top     Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# freq                                                 7608
#
#                       source_name            source_website
# count                       86512                     86512
# unique                         81                       119
# top     World Health Organization  https://covid19.who.int/
# freq                        26822                     25951

# %%
#Cantidad de vacunas aplicadas de cada compañía
vacunas_por_compania[["vaccines","total_vaccinations"]].groupby("vaccines").sum()
print(vacunas_por_compania)
# Out:
#                                              vaccines  total_vaccinations
# 0   Abdala, Johnson&Johnson, Oxford/AstraZeneca, P...        1.784348e+08
# 1   Abdala, Moderna, Oxford/AstraZeneca, Pfizer/Bi...        1.791450e+10
# 2   Abdala, Sinopharm/Beijing, Sinovac, Soberana02...        4.228568e+08
# 3                   Abdala, Soberana Plus, Soberana02        6.405166e+09
# 4   COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/As...        1.069480e+10
# ..                                                ...                 ...
# 79                 Pfizer/BioNTech, Sinovac, Turkovac        3.392310e+10
# 80                         Pfizer/BioNTech, Sputnik V        3.863380e+06
# 81               QazVac, Sinopharm/Beijing, Sputnik V        3.585429e+09
# 82                                  Sinopharm/Beijing        3.080671e+07
# 83                       Sinopharm/Beijing, Sputnik V        6.451243e+08
#
# [84 rows x 2 columns]

# %%
#Cantidad de vacunas aplicadas en todo el mundo
vacunas_aplicadas_mundo = df["total_vaccinations"].sum()
print(f"Total global de vacunas: {vacunas_aplicadas_mundo:,.2f}")
# Out:
# Total global de vacunas: 2,002,854,013,761.00

# %%
#Promedio de vacunas aplicadas por país
promedio_vacunas_por_pais = df.groupby("country")["total_vaccinations"].mean()
print("Promedio de vacunas aplicadas por pais:")
print(promedio_vacunas_por_pais)
# Out:
# Promedio de vacunas aplicadas por pais:
# country
# Afghanistan          2.566118e+06
# Albania              1.191695e+06
# Algeria              9.956086e+06
# Andorra              5.827721e+04
# Angola               6.074066e+06
#                          ...
# Wales                4.132861e+06
# Wallis and Futuna    9.142925e+03
# Yemen                4.794049e+05
# Zambia               1.048484e+06
# Zimbabwe             4.181618e+06
# Name: total_vaccinations, Length: 223, dtype: float64

# %%
#Cantidad de vacunas aplicadas el día 29/01/21

#Convertir la columna 'date' a formato datetime64
df["date"] = pd.to_datetime(df["date"])

#filtrar por fecha
vacunas_21_01_29 = df[df["date"] == "2021-01-29"]

#Suma de vacunas aplicadas en todo el mundo ese día
vacunas_21_01_29 = vacunas_21_01_29["total_vaccinations"].sum()

print("Total global de vacunas aplicadas el 2021-01-29:", vacunas_21_01_29)
# Out:
# Total global de vacunas aplicadas el 2021-01-29: 82952931.0

# %%
#Dataframe nuevo llamado conDiferencias
conDiferencias = df.copy()

# Calcular las diferencias entre las columnas daily_vaccinations y daily_vaccinations_raw
conDiferencias["diferencias"] = df["daily_vaccinations"]-df["daily_vaccinations_raw"]

# Mostrar el nuevo dataframe
print(conDiferencias.head())
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
#Obtener el periodo de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua
fecha_mas_reciente = df["date"].max()
fecha_mas_antigua =df["date"].min()

#Obtener la diferencia de tiempo
periodo_tiempo = fecha_mas_reciente - fecha_mas_antigua

print("Fecha más reciente:", fecha_mas_reciente)
print("Fecha más antigua:", fecha_mas_antigua)
print("Periodo de tiempo entre el registro más reciente y el registro más antiguo::", periodo_tiempo)
# Out:
# Fecha más reciente: 2022-03-29 00:00:00
# Fecha más antigua: 2020-12-02 00:00:00
# Periodo de tiempo entre el registro más reciente y el registro más antiguo:: 482 days 00:00:00

# %%
#Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac)
#con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter , ).

#vacunas_por_dia = df["vaccines"].str.split(",", expand=True)
#df["canVac"] = vacunas_por_dia.count(axis=1)
#df.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
#Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.
#filtrar por fecha
antes20 = df[df["date"] < "2020-12-20"]
print(antes20.head())
# Out:
#       country iso_code       date  total_vaccinations  people_vaccinated  \
# 13403  Canada      CAN 2020-12-14                 5.0                5.0
# 13404  Canada      CAN 2020-12-15               727.0              727.0
# 13405  Canada      CAN 2020-12-16              3025.0             3025.0
# 13406  Canada      CAN 2020-12-17              7279.0             7279.0
# 13407  Canada      CAN 2020-12-18             11296.0            11296.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 13403                      NaN                     NaN                 NaN
# 13404                      NaN                   722.0               722.0
# 13405                      NaN                  2298.0              1510.0
# 13406                      NaN                  4254.0              2425.0
# 13407                      NaN                  4017.0              2823.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
#Dataframe llamado pfizer
# Filtrar los registros que contienen la vacuna Pfizer
pfizer = df[df["vaccines"].str.contains("Pfizer")]

# Mostrar el nuevo dataframe pfizer
print(pfizer)
# Out:
#            country  iso_code       date  total_vaccinations  \
# 0      Afghanistan       AFG 2021-02-22                 0.0
# 1      Afghanistan       AFG 2021-02-23                 NaN
# 2      Afghanistan       AFG 2021-02-24                 NaN
# 3      Afghanistan       AFG 2021-02-25                 NaN
# 4      Afghanistan       AFG 2021-02-26                 NaN
# ...            ...       ...        ...                 ...
# 85069        Wales  OWID_WLS 2022-03-24           6921195.0
# 85070        Wales  OWID_WLS 2022-03-25           6923298.0
# 85071        Wales  OWID_WLS 2022-03-26           6923706.0
# 85072        Wales  OWID_WLS 2022-03-27           6925183.0
# 85073        Wales  OWID_WLS 2022-03-28           6927437.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
# Crear un objeto ExcelWriter

with pd.ExcelWriter("resultadosReto.xlsx") as writer:
    # Almacenar los dataframes en hojas separadas
    conDiferencias.to_excel(writer, sheet_name="conDiferencias", index=False)
    conCantidad.to_excel(writer, sheet_name="conCantidad", index=False)
    antes20.to_excel(writer, sheet_name="antes20", index=False)
    pfizer.to_excel(writer, sheet_name="pfizer", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-86-2118041299.py in <cell line: 0>()
#       4     # Almacenar los dataframes en hojas separadas
# ----> 5     conDiferencias.to_excel(writer, sheet_name="conDiferencias", index=False)
#       6     conCantidad.to_excel(writer, sheet_name="conCantidad", index=False)
#
# NameError: name 'conDiferencias' is not defined
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-86-2118041299.py in <cell line: 0>()
#       1 # Crear un objeto ExcelWriter
#       2
# ----> 3 with pd.ExcelWriter("resultadosReto.xlsx") as writer:
#       4     # Almacenar los dataframes en hojas separadas
#       5     conDiferencias.to_excel(writer, sheet_name="conDiferencias", index=False)
#
# ...
